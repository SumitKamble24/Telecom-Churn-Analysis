# %% [markdown]
# <a href="https://colab.research.google.com/github/SumitKamble24/Telecom-Churn-Analysis/blob/main/Team_Telecom_Churn_Analysis__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Drivebit/Telecom Churn.csv')

# %%
df
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 0       KS             128  ...                       1  False
# 1       OH             107  ...                       1  False
# 2       NJ             137  ...                       0  False
# 3       OH              84  ...                       2  False
# 4       OK              75  ...                       3  False
# ...    ...             ...  ...                     ...    ...
# 3328    AZ             192  ...                       2  False
# 3329    WV              68  ...                       3  False
# 3330    RI              28  ...                       2  False
# 3331    CT             184  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [3333 rows x 20 columns]

# %%
plt.figure(figsize=(16,8))
sns.barplot(x=df['Customer service calls'], y=df['Churn'],ci= None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Account length    Area code  ...  Total intl charge  Customer service calls
# count     3333.000000  3333.000000  ...        3333.000000             3333.000000
# mean       101.064806   437.182418  ...           2.764581                1.562856
# std         39.822106    42.371290  ...           0.753773                1.315491
# min          1.000000   408.000000  ...           0.000000                0.000000
# 25%         74.000000   408.000000  ...           2.300000                1.000000
# 50%        101.000000   415.000000  ...           2.780000                1.000000
# 75%        127.000000   510.000000  ...           3.270000                2.000000
# max        243.000000   510.000000  ...           5.400000                9.000000
#
# [8 rows x 16 columns]

# %%
### creat bar plot for checking international plan call status
x,y = np.unique(df['International plan'],return_counts=True)
sns.barplot(x,y)
plt.xlabel("International Plan")
plt.ylabel("Count")
plt.title('International Call Status')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'International Call Status')

# %%
# series of counts
intl_status = df['International plan'].value_counts()
# print the counts
print(intl_status)
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %%
intl_status.plot(kind='pie',autopct='%1.1f%%')
plt.title('International call plan status')
# Out:
# Text(0.5, 1.0, 'International call plan status')

# %%
### creat bar plot for checking Voice mail plan Status

x,y = np.unique(df['Voice mail plan'],return_counts=True)
sns.barplot(x,y)
plt.xlabel("Voice mail plan")
plt.ylabel("Count")
plt.title('Voice mail plan Status')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Voice mail plan Status')

# %%
# series of counts
vml_status = df['Voice mail plan'].value_counts()
# print the counts
print(vml_status)
vml_status.plot(kind='pie',autopct='%1.1f%%')
plt.title('Voice mail plan status')
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64
# Text(0.5, 1.0, 'Voice mail plan status')

# %%
### creat bar plot for checking Churn Status

x,y = np.unique(df['Churn'],return_counts=True)
sns.barplot(x,y)
plt.xlabel("Churn")
plt.ylabel("Count")
plt.title('Churn Status')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Churn Status')

# %%
# series of counts
churn_status = df['Churn'].value_counts()
# print the counts
print(churn_status)
churn_status.plot(kind='pie',autopct='%1.1f%%')
plt.title('Churn status')
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64
# Text(0.5, 1.0, 'Churn status')

# %%
## sum of total day minutes

total_day_minutes = round(df['Total day minutes'].sum(),2)
total_day_minutes
# Out:
# 599190.4

# %%
## sum of total eve minutes
total_eve_minutes = round(df['Total eve minutes'].sum(),2)
total_eve_minutes
# Out:
# 669867.5

# %%
## sum of total Night minutes

total_night_minutes = round(df['Total night minutes'].sum(),2)
total_night_minutes
# Out:
# 669506.5

# %%
### Sum of total int Minutes
total_intl_minutes = round(df['Total intl minutes'].sum(),2) 
total_intl_minutes
# Out:
# 34120.9

# %%
plotdata = pd.DataFrame(
    {"Minutes": [total_day_minutes, total_eve_minutes, total_night_minutes, total_intl_minutes]}, 
    index=["total_day_minutes", "total_eve_minutes", "total_night_minutes", "total_intl_minutes"])
# Plot a bar chart
plotdata.plot(kind="bar")

plt.xlabel('Total Minutes')
plt.ylabel('Count')
plt.title('Total minutes of calls in different parts of a whole day')
# Out:
# Text(0.5, 1.0, 'Total minutes of calls in different parts of a whole day')

# %%
plt.figure(figsize=(5,5))
plt.plot(kind = 'pie',subplots=True, autopct='%1.1f%%', explode=[0.05]*4)
# Out:
# []

# %%
## sum of Total day calls

total_day_calls = round(df['Total day calls'].sum(),2)
total_day_calls
# Out:
# 334752

# %%
## Sum of Total eve calls
total_eve_calls = round(df['Total eve calls'].sum(),2)
total_eve_calls
# Out:
# 333681

# %%
## Sum of Total noight calls
total_night_calls = round(df['Total night calls'].sum(),2)
total_night_calls
# Out:
# 333659

# %%
## Sum of Total intl calls
total_intl_calls  = round(df['Total intl calls'].sum(),2)
total_intl_calls
# Out:
# 14930

# %%
plotdata1= pd.DataFrame(
    {"Calls": [total_day_calls, total_eve_calls, total_night_calls, total_intl_calls]}, 
    index=["total_day_calls", "total_eve_calls", "total_night_calls", "total_intl_calls"])
# Plot a bar chart
plotdata1.plot(kind="bar")
plt.xlabel('Total Calls')
plt.ylabel('Count')
plt.title('Total Calls dialin different parts of a whole day')
# Out:
# Text(0.5, 1.0, 'Total Calls dialin different parts of a whole day')

# %%
plt.figure(figsize=(5,5))
plotdata1.plot(kind = 'pie',subplots=True, autopct='%1.1f%%',explode=[0.05]*4)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9cbe5e18d0>],
#       dtype=object)

# %%
## Sum of Total day charge
total_day_charge = round(df['Total day charge'].sum(),2)
total_day_charge
# Out:
# 101864.17

# %%
## Sum of Total eve charge
total_eve_charge = round(df['Total eve charge'].sum(),2)
total_eve_charge
# Out:
# 56939.44

# %%
## Sum of Total night charge
total_night_charge = round(df['Total night charge'].sum(),2)
total_night_charge
# Out:
# 30128.07

# %%
## Sum of Total intl charge
total_intl_charge = round(df['Total intl charge'].sum(),2)
total_intl_charge
# Out:
# 9214.35

# %%
plotdata2 = pd.DataFrame(
    {"Charges": [total_day_charge, total_eve_charge, total_night_charge, total_intl_charge]}, 
    index=["total_day_charge", "total_eve_charge", "total_night_charge", "total_intl_charge"])
# Plot a bar chart
plt.figure(figsize = (20,10))
plotdata2.plot(kind="bar")
plt.xlabel('Total Charges')
plt.ylabel('Count')
plt.title('Total Charges of calls in different parrts of whole day')
# Out:
# Text(0.5, 1.0, 'Total Charges of calls in different parrts of whole day')

# %%
plotdata2.plot(kind = 'pie',subplots=True, autopct='%1.1f%%', explode=[0.05]*4)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9cbe566950>],
#       dtype=object)

# %%
#let see how many states in data
a =set(df['State'])

# %%
len(a)
# Out:
# 51

# %%
# create plot for churn values
x,y = np.unique(df['Churn'],return_counts=True)
sns.barplot(x,y)
plt.xlabel('Churn Status')
plt.ylabel('Total Count')
plt.title('Churn Status and Total Count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# bar plot for churn and customer service calls
plt.figure(figsize=(16,8))
sns.set_theme(style="whitegrid")
sns.barplot(x=df['Customer service calls'],y=df['Churn'],palette="Blues_d",ci=0.68)
plt.title('Rate churn with respect to customer service call')
# Out:
# Text(0.5, 1.0, 'Rate churn with respect to customer service call')

# %%
plt.figure(figsize=(16,8))
sns.set_theme(style="whitegrid")
sns.barplot(x=df['State'],y=df['Churn'],palette="Blues_d",ci=None)

# %%
# bar plot for churn and Total international calls
plt.figure(figsize=(16,8))
sns.set_theme(style="whitegrid")
sns.barplot(x=df['Total intl calls'],y=df['Churn'],palette="Blues_d",ci=None)
plt.xlabel("Total international calls")
plt.title('Rate churn with respect to Total international calls')
# Out:
# Text(0.5, 1.0, 'Rate churn with respect to Total international calls')

# %%
# state vs Number vmail messages 
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Number vmail messages'], color='y')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Number vmail messages')
plt.show()

# %%
# state vs Total day calls 
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Total day calls'], color='c')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Total day calls')
plt.show()

# %%
# state vs Total eve calls 
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Total eve calls'], color='g')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Total eve calls')
plt.show()

# %%
# state vs Total night calls
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Total night calls'], color='firebrick')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Total night calls')
plt.show()

# %%
# state vs Customer service calls
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Customer service calls'], color='royalblue')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Customer service calls')
plt.show()

# %%
# state vs Total intl calls
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Total intl calls'], color='0.75')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Total intl calls')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.bar(df['State'],df['Total eve calls'], color='g')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.xlabel('State')
plt.ylabel('Total eve calls')
plt.show()
